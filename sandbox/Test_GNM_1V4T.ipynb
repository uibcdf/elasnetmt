# %% [markdown]
# # Test GNM

# %%
import molsysmt as msm
import enmt as enm
import molsysmt as msm
import nglview as nv
from molsysmt import pyunitwizard as puw
from tqdm import tqdm
from matplotlib import pyplot as plt
# Out:
# /home/diego/Myopt/miniconda3/envs/enmt@uibcdf_3.12/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
my_gnm = enm.GaussianNetworkModel('1V4T', selection='atom_name=="CA"', cutoff='7.0 angstroms')

# %%
my_gnm.view_mode(mode=2)
# Out:
# NGLWidget()

# %%
view = msm.view(my_gnm.molecular_system)

# %%
nv.write_html('1V4T.html', view)

# %%
view.clear()

# %%
msm.thirds.nglview.set_color_by_value(view, my_gnm.modes[1], element='group', cmap=plt.colormaps['bwr'])

# %%
view
# Out:
# NGLWidget()

# %%
import matplotlib.pyplot as plt

# %%
type(plt.colormaps['bwr'])
# Out:
# matplotlib.colors.LinearSegmentedColormap

# %%
cmap = plt.colormaps['bwr']

# %%
from matplotlib.colors import LinearSegmentedColormap

# %%
isinstance(cmap, LinearSegmentedColormap)
# Out:
# True

# %%
import numpy as np

# %%
plt.scatter(list(range(len(my_gnm.frequencies))), my_gnm.frequencies)

# %%
my_gnm.view_model(protein=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 my_gnm.view_model(protein=True)
#
# AttributeError: 'GaussianNetworkModel' object has no attribute 'view_model'

# %%
my_gnm.view(protein=True, network=True)
# Out:
# NGLWidget()

# %%
my_gnm.show_contact_map()

# %%
my_gnm.contacts.shape
# Out:
# (424, 424)

# %%
import matplotlib.pyplot as plt

# %%
plt.matshow(my_gnm.contacts, cmap='binary')

# %%
my_gnm.show_correlation_matrix()

# %%
my_gnm.show_b_factors()
# Out:
# /home/diego/Myopt/miniconda3/envs/enmt@uibcdf_3.12/lib/python3.12/site-packages/matplotlib/cbook.py:1355: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)

# %%
my_gnm.show_b_factors_dispersion()
# Out:
# /home/diego/Myopt/miniconda3/envs/enmt@uibcdf_3.12/lib/python3.12/site-packages/sklearn/utils/_array_api.py:757: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   array = numpy.asarray(array, order=order, dtype=dtype)
# /home/diego/Myopt/miniconda3/envs/enmt@uibcdf_3.12/lib/python3.12/site-packages/sklearn/utils/_array_api.py:757: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   array = numpy.asarray(array, order=order, dtype=dtype)

# %%
my_gnm.show_best_cutoff()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 70/70 [01:47<00:00,  1.53s/it]
# /home/diego/Myopt/miniconda3/envs/enmt@uibcdf_3.12/lib/python3.12/site-packages/matplotlib/cbook.py:1355: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)

# %%
plt.plot(my_gnm.modes[2])
